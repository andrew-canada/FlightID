# %%
import pydeck as pdk
import pandas as pd
import json
import numpy as np

#loading datasets
coordinates = json.load(open("../data/airport_coordinates.json",'r'))
df = pd.read_csv("../outputs/inflated_flights.csv")



df["src_lat"] = [coordinates[i][0] for i in df["city1"]]
df["src_lon"] = [coordinates[i][1] for i in df["city1"]]
df["dst_lat"] = [coordinates[i][0] for i in df["city2"]]
df["dst_lon"] = [coordinates[i][1] for i in df["city2"]]
df["pretty_dif"] = [round(i,2) for i in df["pct_diff"]]

# print(df.head())
avg = np.average(df["pct_diff"])
# print(df)
layers = []
for row in df.to_dict(orient="records"):
    # highlight = avg<row["pct_diff"]
    # act_dif =row["pct_diff"] * (-1 if row["actual_fare"] < row["predicted_fare"] else 1)
    layer = pdk.Layer(
        "ArcLayer",
        data=[row],
        get_source_position=["src_lon", "src_lat"],
        get_target_position=["dst_lon", "dst_lat"],
        get_source_color=[70 +(70000* max((row["pct_diff"]-avg),0)), 70+(5000* max(-(row["pct_diff"]-avg),0)), 20], # red ish if the fare is expensive green if it is chaper than the avg model difference
        get_target_color=[150, 150, 150],   # cyan at destination
        get_width=1.2,
        pickable=True,
        auto_highlight=True,
    )
    layers.append(layer)

# print(layers)


view_state = pdk.ViewState(
    latitude=40.0,
    longitude=-100.0,
    zoom=3.5,
    pitch=60,
    bearing=20,
)
r = pdk.Deck(
    layers=layers,
    initial_view_state=view_state,
    map_style="https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
    tooltip={"html": "{city1} → {city2}\nAvg. Fare: {actual_fare}\n Pred:{predicted_fare} \n Difference from Predicted(ratio): {pretty_dif}"},
)

# Map of predicted model differences from actual fare prices
r
# Out:
# {
#   "initialViewState": {
#     "bearing": 20,
#     "latitude": 40.0,
#     "longitude": -100.0,
#     "pitch": 60,
#     "zoom": 3.5
#   },
#   "layers": [
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 311.5,
#           "city1": "Albany, NY",
#           "city2": "Atlanta, GA (Metropolitan Area)",
#           "dst_lat": 33.6407,
#           "dst_lon": -84.4277,
#           "pct_diff": 0.1625590042704005,
#           "predicted_fare": 267.94338941574097,
#           "pretty_dif": 0.16,
#           "src_lat": 42.7473,
#           "src_lon": -73.8014,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Los Angeles, CA (Metropolitan Area);Miami, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         275.37135615723037,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "de6a8b5d-4ee2-4da2-ab65-a343e9d707f9",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 460.14,
#           "city1": "Albany, NY",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2072253553502633,
#           "predicted_fare": 381.1550163030624,
#           "pretty_dif": 0.21,
#           "src_lat": 42.7473,
#           "src_lon": -73.8014,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Miami, FL (Metropolitan Area);Miami, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         321.44558938917066,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "bdd91d2b-75a0-46e7-a8d6-fb0a4c1571fc",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 192.12,
#           "city1": "Albuquerque, NM",
#           "city2": "Las Vegas, NV",
#           "dst_lat": 36.084,
#           "dst_lon": -115.1537,
#           "pct_diff": 0.1782937680004171,
#           "predicted_fare": 163.0493220090866,
#           "pretty_dif": 0.18,
#           "src_lat": 35.0402,
#           "src_lon": -106.609,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         196.69753750714733,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "0f9c18d3-7dec-412b-b0f2-44f2ebe93099",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 189.01,
#           "city1": "Albuquerque, NM",
#           "city2": "Las Vegas, NV",
#           "dst_lat": 36.084,
#           "dst_lon": -115.1537,
#           "pct_diff": 0.1639264604686821,
#           "predicted_fare": 162.38998460769653,
#           "pretty_dif": 0.16,
#           "src_lat": 35.0402,
#           "src_lon": -106.609,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         268.5340751658224,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "7ebad715-3c91-4f06-ae7c-0e8adaffbc96",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare":
los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         298.8666786890724,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "627e340d-f06d-4d92-a01f-6b574f8e9e96",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 332.98,
#           "city1": "Austin, TX",
#           "city2": "Philadelphia, PA",
#           "dst_lat": 39.8721,
#           "dst_lon": -75.2411,
#           "pct_diff": 0.165532958022482,
#           "predicted_fare": 285.6890469789505,
#           "pretty_dif": 0.17,
#           "src_lat": 30.1975,
#           "src_lon": -97.6664,
#           "suggested_alternatives": "Boston, MA (Metropolitan Area);Seattle, WA;Boston, MA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         260.50158739682286,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "850104fb-375d-413c-b115-814ee99609f1",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 240.21,
#           "city1": "Austin, TX",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.1719382142822124,
#           "predicted_fare": 204.96814343333244,
#           "pretty_dif": 0.17,
#           "src_lat": 30.1975,
#           "src_lon": -97.6664,
#           "suggested_alternatives": "Boston, MA (Metropolitan Area);Seattle, WA;Boston, MA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         228.47530609817085,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "5b4f84cc-8c6e-4203-97e9-7a4a06b1ea6e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 242.27,
#           "city1": "Birmingham, AL",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2878755167871519,
#           "predicted_fare": 188.11600720882416,
#           "pretty_dif": 0.29,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         5966.956889971373,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "f9f401dd-2446-481c-88f6-8adece9bf626",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 239.57,
#           "city1": "Birmingham, AL",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.3789644188915873,
#           "predicted_fare": 173.73182129859924,
#           "pretty_dif": 0.38,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         12343.180037281849,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "64176ea4-919c-4420-8ffd-f7d675ec1e4c",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 406.12,
#           "city1": "Birmingham, AL",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.15272857164674,
#           "predicted_fare": 352.3119058459997,
#           "pretty_dif": 0.15,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         324.52351927553286,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "d573cec5-7cef-4e5b-b195-55628e3fe08d",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 195.92,
#           "city1": "Boise, ID",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.1764746874156207,
#           "predicted_fare": 166.53141975402832,
#           "pretty_dif": 0.18,
#           "src_lat": 43.5644,
#           "src_lon": -116.2228,
#           "suggested_alternatives": "Orlando, FL;Orlando, FL;Chicago, IL"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         205.79294043112935,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "a81468f7-e560-4ba5-b84b-f1e422b383f7",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 199.72,
#           "city1": "Boise, ID",
#           "city2": "Spokane, WA",
#           "dst_lat": 47.6199,
#           "dst_lon": -117.5338,
#           "pct_diff": 0.1548413327632457,
#           "predicted_fare": 172.9415066242218,
#           "pretty_dif": 0.15,
#           "src_lat": 43.5644,
#           "src_lon": -116.2228,
#           "suggested_alternatives": "Orlando, FL;Orlando, FL;Chicago, IL"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         313.9597136930044,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "d854a2cc-e499-4967-9043-43dccfd60866",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 344.42,
# ...
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "af25e5d9-7c44-4b13-9206-102bd2ab8cc1",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 229.23,
#           "city1": "Reno, NV",
#           "city2": "San Diego, CA",
#           "dst_lat": 32.7338,
#           "dst_lon": -117.1933,
#           "pct_diff": 0.2026226310076607,
#           "predicted_fare": 190.60842037200928,
#           "pretty_dif": 0.2,
#           "src_lat": 39.4991,
#           "src_lon": -119.7682,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area);Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         75.05322247092931,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "44ab4749-f72e-4da0-bc8d-43e190a2121c",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 178.59,
#           "city1": "Richmond, VA",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1569920275467684,
#           "predicted_fare": 154.3571569621563,
#           "pretty_dif": 0.16,
#           "src_lat": 37.5051,
#           "src_lon": -77.3194,
#           "suggested_alternatives": "San Francisco, CA (Metropolitan Area);San Francisco, CA (Metropolitan Area);San Francisco, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         303.20623977539094,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "0925e948-ffc0-4039-a4ac-6f1ed9d0e9bb",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 180.55,
#           "city1": "Richmond, VA",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2327575873637923,
#           "predicted_fare": 146.46026262640953,
#           "pretty_dif": 0.23,
#           "src_lat": 37.5051,
#           "src_lon": -77.3194,
#           "suggested_alternatives": "San Francisco, CA (Metropolitan Area);San Francisco, CA (Metropolitan Area);San Francisco, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         
://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json          |
# | ⬜ Positron (light)         | https://basemaps.cartocdn.com/gl/positron-gl-style/style.json             |
# | 🗺️ Voyager (color)        | https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json              |
# | 🌑 Dark Matter (no labels) | https://basemaps.cartocdn.com/gl/dark-matter-nolabels-gl-style/style.json |
# | ⬜ Positron (no labels)     | https://basemaps.cartocdn.com/gl/positron-nolabels-gl-style/style.json    |
# | 🗺️ Voyager (no labels)    | https://basemaps.cartocdn.com/gl/voyager-nolabels-gl-style/style.json     |
#
# For color intensity/ density, edit the numbers. Note that the negative signs (red/green) may change depending on the use case

# %%
import math

def is_long_distance(lat1, lon1, lat2, lon2, threshold_km=2000):
    """
    Returns True if the flight distance between two coordinates exceeds threshold.
    Default threshold: 1500 km (~930 miles) — roughly NYC to Denver.
    """
    R = 6371  # Earth radius in km

    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    distance_km = 2 * R * math.asin(math.sqrt(a))

    return distance_km >= threshold_km, round(distance_km)

layers=[]

for row in df.to_dict(orient="records"):
    # highlight = avg<row["pct_diff"]
    # act_dif =row["pct_diff"] * (-1 if row["actual_fare"] < row["predicted_fare"] else 1)
    check, dist = is_long_distance(row["src_lat"],
                            row["src_lon"],
                            row["dst_lat"],
                            row["dst_lon"])
    # print(dist)
    if not check:
        continue
    layer = pdk.Layer(
        "ArcLayer",
        data=[row],
        get_source_position=["src_lon", "src_lat"],
        get_target_position=["dst_lon", "dst_lat"],
        get_source_color=[70 +(70000* max((row["pct_diff"]-avg),0)), 70+(5000* max(-(row["pct_diff"]-avg),0)), 20],   # pink at origin
        get_target_color=[150+(20000* max((row["pct_diff"]-avg),0)), 150+(1000* max(-(row["pct_diff"]-avg),0)), 150],   # cyan at destination
        get_width=1.2,
        pickable=True,
        auto_highlight=True,
    )
    layers.append(layer)

v = pdk.Deck(
    layers=layers,
    initial_view_state=view_state,
    map_style="https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
    tooltip={"html": "{city1} → {city2}\nAvg. Fare: {actual_fare}\n Pred:{predicted_fare} \n Difference from Predicted(ratio): {pretty_dif}"},
)
v
# Map of predicted model differences from actual fare prices for long distance flights only 
v
# Out:
# {
#   "initialViewState": {
#     "bearing": 20,
#     "latitude": 40.0,
#     "longitude": -100.0,
#     "pitch": 60,
#     "zoom": 3.5
#   },
#   "layers": [
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 460.14,
#           "city1": "Albany, NY",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2072253553502633,
#           "predicted_fare": 381.1550163030624,
#           "pretty_dif": 0.21,
#           "src_lat": 42.7473,
#           "src_lon": -73.8014,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Miami, FL (Metropolitan Area);Miami, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         321.44558938917066,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         221.84159696833447,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "f0590510-70c3-4cc9-b35f-05efefaa5afc",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 372.25,
#           "city1": "Albuquerque, NM",
#           "city2": "Boston, MA (Metropolitan Area)",
#           "dst_lat": 42.3656,
#           "dst_lon": -71.0096,
#           "pct_diff": 0.1901557235245789,
#           "predicted_fare": 312.7741963863373,
#           "pretty_dif": 0.19,
#           "src_lat": 35.0402,
#           "src_lon": -106.609,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         137.3877598863383,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         163.47755197726767,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "56256a6a-8dfb-484b-840f-01031ad16428",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 423.35,
#           "city1": "Atlanta, GA (Metropolitan Area)",
#           "city2": "Salt Lake City, UT",
#           "dst_lat": 40.7899,
#           "dst_lon": -111.9791,
#           "pct_diff": 0.1982068887842433,
#           "predicted_fare": 353.31961780786514,
#           "pretty_dif": 0.2,
#           "src_lat": 33.6407,
#           "src_lon": -84.4277,
#           "suggested_alternatives": "Seattle, WA;Trenton, NJ;Trenton, NJ"
#         }
#       ],
#       "getSourceColor": [
#         70,
#

#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "7b70ac4c-b367-43c7-acfd-6d8cedd6d1e3",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 332.98,
#           "city1": "Austin, TX",
#           "city2": "Philadelphia, PA",
#           "dst_lat": 39.8721,
#           "dst_lon": -75.2411,
#           "pct_diff": 0.165532958022482,
#           "predicted_fare": 285.6890469789505,
#           "pretty_dif": 0.17,
#           "src_lat": 30.1975,
#           "src_lon": -97.6664,
#           "suggested_alternatives": "Boston, MA (Metropolitan Area);Seattle, WA;Boston, MA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         260.50158739682286,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         188.10031747936458,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "b17281a1-fe82-4e2e-b8d9-8bf17a88ebb5",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 240.21,
#           "city1": "Austin, TX",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.1719382142822124,
#           "predicted_fare": 204.96814343333244,
#           "pretty_dif": 0.17,
#           "src_lat": 30.1975,
#           "src_lon": -97.6664,
#           "suggested_alternatives": "Boston, MA (Metropolitan Area);Seattle, WA;Boston, MA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         228.47530609817085,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         181.69506121963417,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "9ba80c0a-6b84-4c5f-affe-674f5cb1e995",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 406.12,
#           "city1": "Birmingham, AL",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.15272857164674,
#           "predicted_fare": 352.3119058459997,
#           "pretty_dif": 0.15,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         324.52351927553286,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         200.90470385510656,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "c00b4dad-7300-4c1f-9890-d84fdaf5caa7",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 344.42,
#           "city1": "Boise, ID",
#           "city2": "Chicago, IL",
#           "dst_lat": 41.9742,
#           "dst_lon": -87.9073,
#           "pct_diff": 0.2177636972796317,
#           "predicted_fare": 282.8299125432968,
#           "pretty_dif": 0.22,
#           "src_lat": 43.5644,
#           "src_lon": -116.2228,
#           "suggested_alternatives": "Orlando, FL;Orlando, FL;Phoenix, AZ"
#         }
#       ],
#       "getSourceColor": [
#         1059.1295244449602,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         432.6084355557029,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "8e0dc72d-4caa-4002-913a-3271c2c06705",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 319.69,
#           "city1": "Boston, MA (Metropolitan Area)",
#           "city2": "Kansas City, MO",
#           "dst_lat": 39.2976,
#           "dst_lon": -94.7139,
#           "pct_diff": 0.1612646107325543,
#           "predicted_fare": 275.2947063446045,
#           "pretty_dif": 0.16,
#           "src_lat": 42.3656,
#           "src_lon": -71.0096,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         281.8433238464613,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         192.36866476929225,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "79372daf-e92d-41e0-bbd2-7e6853da5f42",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 312.92,
#           "city1": "Boston, MA (Metropolitan Area)",
#           "city2": "Houston, TX",
#           "dst_lat": 29.9902,
#           "dst_lon": -95.3368,
#           "pct_diff": 0.1616858194477125,
#           "predicted_fare": 269.3671513944864,
#           "pretty_dif": 0.16,
#           "src_lat": 42.3656,
#           "src_lon": -71.0096,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         279.7372802706704,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         191.94745605413408,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "5d0ec25b-dc85-4bc1-a5f1-e013267534b2",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 404.41,
#           "city1": "Boston, MA (Metropolitan Area)",
#           "city2": "Salt Lake City, UT",
#           "dst_lat": 40.7899,
#           "dst_lon": -111.9791,
#           "pct_diff": 0.2136172027047689,
#           "predicted_fare": 333.2269838452339,
#           "pretty_dif": 0.21,
#           "src_lat": 42.3656,
#           "src_lon": -71.0096,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         768.8749042045625,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         349.6785440584464,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "cbacb269-19eb-44c3-a2c7-9e7723165a9d",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 471.55,
#           "city1": "Boston, MA (Metropolitan Area)",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.2283305276049825,
#           "predicted_fare": 383.8950424194336,
#           "pretty_dif": 0.23,
#           "src_lat": 42.3656,
#           "src_lon": -71.0096,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         1798.8076472195144,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         643.9450420627184,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "f1e753ad-c9b1-4180-b7a2-58cf55f469bf",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 339.49,
#           "city1": "Boston, MA (Metropolitan Area)",
#           "city2": "Denver, CO",
#           "dst_lat": 39.8561,
#           "dst_lon": -104.6737,
#           "pct_diff": 0.1956815044001625,
#           "predicted_fare": 283.9301258325577,
#           "pretty_dif": 0.2,
#           "src_lat": 42.3656,
#           "src_lon": -71.0096,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         109.75885550842037,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         157.95177110168407,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "855d79a4-4b1b-4f00-ab7a-d4c4c115a07a",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 375.93,
#           "city1": "Charleston, SC",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.1754847506028488,
#           "predicted_fare": 319.8084873557091,
#           "pretty_dif": 0.18,
#           "src_lat": 32.8986,
#           "src_lon": -80.0405,
#           "suggested_alternatives": "Las Vegas, NV;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         210.74262449498886,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         178.14852489899778,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "6ad5010c-5a87-41ad-84c1-cab44954bd7e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 310.62,
#           "city1": "Chicago, IL",
#           "city2": "Salt Lake City, UT",
#           "dst_lat": 40.7899,
#           "dst_lon": -111.9791,
#           "pct_diff": 0.17116739276265,
#           "predicted_fare": 265.2225479632616,
#           "pretty_dif": 0.17,
#           "src_lat": 41.9742,
#           "src_lon": -87.9073,
#           "suggested_alternatives": "Seattle, WA;Los Angeles, CA (Metropolitan Area);Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         232.32941369598282,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         182.46588273919656,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "bbcdf164-de5d-4752-b6a2-9707415ffbab",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 334.0,
#           "city1": "Chicago, IL",
#           "city2": "Portland, OR",
#           "dst_lat": 45.5887,
#           "dst_lon": -122.5975,
#           "pct_diff": 0.1551803930831773,
#           "predicted_fare": 289.13233119249344,
#           "pretty_dif": 0.16,
#           "src_lat": 41.9742,
#           "src_lon": -87.9073,
#           "suggested_alternatives": "Seattle, WA;Los Angeles, CA (Metropolitan Area);Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         312.2644120933463,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         198.45288241866928,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "35eae23d-54c6-4a68-9ce0-62197f258b94",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 277.77,
#           "city1": "Chicago, IL",
#           "city2": "Salt Lake City, UT",
#           "dst_lat": 40.7899,
#           "dst_lon": -111.9791,
#           "pct_diff": 0.170978614409953,
#           "predicted_fare": 237.21184706687927,
#           "pretty_dif": 0.17,
#           "src_lat": 41.9742,
#           "src_lon": -87.9073,
#           "suggested_alternatives": "Seattle, WA;Los Angeles, CA (Metropolitan Area);Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         233.27330545946788,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         182.6546610918936,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "c1250881-ba0a-45ed-a600-078e1543279c",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 358.54,
#           "city1": "Cincinnati, OH",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2189706463735875,
#           "predicted_fare": 294.1334158182144,
#           "pretty_dif": 0.22,
#           "src_lat": 39.0489,
#           "src_lon": -84.6678,
#           "suggested_alternatives": "Punta Gorda, FL;Seattle, WA;Punta Gorda, FL"
#         }
#       ],
#       "getSourceColor": [
#         1143.6159610218663,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         456.74741743481894,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "a2dd4080-3d43-4a6e-a22b-684fd9aa5b41",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 308.57,
#           "city1": "Cleveland, OH (Metropolitan Area)",
#           "city2": "San Diego, CA",
#           "dst_lat": 32.7338,
#           "dst_lon": -117.1933,
#           "pct_diff": 0.1830860559186204,
#           "predicted_fare": 260.8178825676441,
#           "pretty_dif": 0.18,
#           "src_lat": 41.4117,
#           "src_lon": -81.8498,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         172.73609791613083,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         170.54721958322617,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "98b684c5-8f3d-451c-80ce-054e33b0cb4e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 423.5,
#           "city1": "Cleveland, OH (Metropolitan Area)",
#           "city2": "Seattle, WA",
#           "dst_lat": 47.4502,
#           "dst_lon": -122.3088,
#           "pct_diff": 0.2283267319640574,
#           "predicted_fare": 344.77797232568264,
#           "pretty_dif": 0.23,
#           "src_lat": 41.4117,
#           "src_lon": -81.8498,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         1798.541952354758,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         643.8691292442165,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "dbb91a39-e607-47d0-87ec-b9fe12740bff",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 333.29,
#           "city1": "Columbus, OH",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2542531497375456,
#           "predicted_fare": 265.72785571217537,
#           "pretty_dif": 0.25,
#           "src_lat": 39.998,
#           "src_lon": -82.8919,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         3613.3911964989315,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1162.3974847139805,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "7da09741-8424-43fe-9ebb-8cdb281a9b39",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 337.83,
#           "city1": "Denver, CO",
#           "city2": "Hartford, CT",
#           "dst_lat": 41.9389,
#           "dst_lon": -72.6832,
#           "pct_diff": 0.1519390759205315,
#           "predicted_fare": 293.2707180976868,
#           "pretty_dif": 0.15,
#           "src_lat": 39.8561,
#           "src_lon": -104.6737,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);Miami, FL (Metropolitan Area);Orlando, FL"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         328.4709979065754,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         201.69419958131508,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "7b3827b1-afcf-4291-b978-9bcabeafb581",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 261.65,
#           "city1": "Denver, CO",
#           "city2": "Hartford, CT",
#           "dst_lat": 41.9389,
#           "dst_lon": -72.6832,
#           "pct_diff": 0.1534351087107002,
#           "predicted_fare": 226.8441440910101,
#           "pretty_dif": 0.15,
#           "src_lat": 39.8561,
#           "src_lon": -104.6737,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);Miami, FL (Metropolitan Area);Orlando, FL"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         320.9908339557318,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         200.19816679114635,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "8b379a34-36ab-4da8-8269-ed2444caccfb",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 437.7,
#           "city1": "Detroit, MI",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.2056408369175273,
#           "predicted_fare": 363.0434426218271,
#           "pretty_dif": 0.21,
#           "src_lat": 42.2124,
#           "src_lon": -83.3534,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         210.52929909765115,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         190.1512283136146,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "33401ce8-7bbf-4523-af9d-7caa24b6c403",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 433.39,
#           "city1": "Detroit, MI",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.1904711853015178,
#           "predicted_fare": 364.0491305887699,
#           "pretty_dif": 0.19,
#           "src_lat": 42.2124,
#           "src_lon": -83.3534,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         135.81045100164386,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         163.16209020032878,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "0689f38e-d89d-47d1-a765-37a7507e4820",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 407.61,
#           "city1": "Detroit, MI",
#           "city2": "Salt Lake City, UT",
#           "dst_lat": 40.7899,
#           "dst_lon": -111.9791,
#           "pct_diff": 0.1860899394236024,
#           "predicted_fare": 343.65859320759773,
#           "pretty_dif": 0.19,
#           "src_lat": 42.2124,
#           "src_lon": -83.3534,
#           "suggested_alternatives": "Las Vegas, NV;Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         157.71668039122076,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         167.54333607824415,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "13378288-5663-425f-b558-ab867c43b3d9",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 362.02,
#           "city1": "Fayetteville, AR",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2462373125915008,
#           "predicted_fare": 290.49041971564293,
#           "pretty_dif": 0.25,
#           "src_lat": 36.0041,
#           "src_lon": -94.17,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area);New York City, NY (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         3052.282596275797,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1002.0807417930848,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "9e316a3b-15d2-4d60-85bd-6771874fe07d",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 339.09,
#           "city1": "Fort Myers, FL",
#           "city2": "Las Vegas, NV",
#           "dst_lat": 36.084,
#           "dst_lon": -115.1537,
#           "pct_diff": 0.2437429370582275,
#           "predicted_fare": 272.63672411441803,
#           "pretty_dif": 0.24,
#           "src_lat": 26.5362,
#           "src_lon": -81.7552,
#           "suggested_alternatives": "New Haven, CT;New Haven, CT;New Haven, CT"
#         }
#       ],
#       "getSourceColor": [
#         2877.6763089466654,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         952.1932311276187,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "b863916a-c34b-4277-8a92-7c5585168e7b",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 424.8,
#           "city1": "Fort Myers, FL",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.2098841654956694,
#           "predicted_fare": 351.10799208283424,
#           "pretty_dif": 0.21,
#           "src_lat": 26.5362,
#           "src_lon": -81.7552,
#           "suggested_alternatives": "New Haven, CT;New Haven, CT;New Haven, CT"
#         }
#       ],
#       "getSourceColor": [
#         507.56229956759876,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         275.01779987645676,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "3f3ff2d1-337f-4444-acad-0fbc1b53f257",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 435.42,
#           "city1": "Fort Myers, FL",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.1858249536123007,
#           "predicted_fare": 367.1874155402184,
#           "pretty_dif": 0.19,
#           "src_lat": 26.5362,
#           "src_lon": -81.7552,
#           "suggested_alternatives": "New Haven, CT;New Haven, CT;New Haven, CT"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         159.04160944772934,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         167.80832188954588,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "03c1eecc-a9ce-4793-8001-915c6aacc29a",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 413.43,
#           "city1": "Hartford, CT",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.1719317437468971,
#           "predicted_fare": 352.7765180915594,
#           "pretty_dif": 0.17,
#           "src_lat": 41.9389,
#           "src_lon": -72.6832,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         228.50765877474734,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         181.70153175494946,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "dc847e15-bf5b-4fa7-abd6-01f6ca75b48c",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 432.61,
#           "city1": "Hartford, CT",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.2342232112573984,
#           "predicted_fare": 350.5119625478983,
#           "pretty_dif": 0.23,
#           "src_lat": 41.9389,
#           "src_lon": -72.6832,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         2211.295502888628,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         761.7987151110366,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "b71f88e1-bcad-49c6-b9f8-091082ad8c05",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 346.02,
#           "city1": "Houston, TX",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.177462300094603,
#           "predicted_fare": 293.8692813962698,
#           "pretty_dif": 0.18,
#           "src_lat": 29.9902,
#           "src_lon": -95.3368,
#           "suggested_alternatives": "New York City, NY (Metropolitan Area);Seattle, WA;Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         200.8548770362178,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         176.17097540724356,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "d4a3a8e3-a69e-4802-9bc4-1750ca8eb70c",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 360.15,
#           "city1": "Indianapolis, IN",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.1528206461786974,
#           "predicted_fare": 312.4076595902443,
#           "pretty_dif": 0.15,
#           "src_lat": 39.7173,
#           "src_lon": -86.2944,
#           "suggested_alternatives": "Punta Gorda, FL;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         324.06314661574584,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         200.81262932314917,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "b5e7184c-0adb-4de0-a55a-c8bb81f00908",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 373.93,
#           "city1": "Indianapolis, IN",
#           "city2": "Los Angeles, CA (Metropolitan Area)",
#           "dst_lat": 33.9425,
#           "dst_lon": -118.4081,
#           "pct_diff": 0.1630335334073024,
#           "predicted_fare": 321.51265570521355,
#           "pretty_dif": 0.16,
#           "src_lat": 39.7173,
#           "src_lon": -86.2944,
#           "suggested_alternatives": "Punta Gorda, FL;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         272.99871047272086,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         190.59974209454418,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "931096f7-5f0f-43e2-b042-833932c06b96",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 388.81,
#           "city1": "Indianapolis, IN",
#           "city2": "Seattle, WA",
#           "dst_lat": 47.4502,
#           "dst_lon": -122.3088,
#           "pct_diff": 0.2069699025648514,
#           "predicted_fare": 322.1372787952423,
#           "pretty_dif": 0.21,
#           "src_lat": 39.7173,
#           "src_lon": -86.2944,
#           "suggested_alternatives": "Punta Gorda, FL;Los Angeles, CA (Metropolitan Area);Las Vegas, NV"
#         }
#       ],
#       "getSourceColor": [
#         303.56389441033826,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         216.73254126009664,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "71ff238e-3704-4540-bdd9-16d9100710bd",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 551.97,
#           "city1": "Jackson, WY",
#           "city2": "New York City, NY (Metropolitan Area)",
#           "dst_lat": 40.6413,
#           "dst_lon": -73.7781,
#           "pct_diff": 0.2719603392589688,
#           "predicted_fare": 433.9522098004818,
#           "pretty_dif": 0.27,
#           "src_lat": 43.6073,
#           "src_lon": -110.7377,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         4852.894462998555,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1516.5412751424444,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "4a5454a2-b8a2-4c12-9fc7-8204f5ccc44e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 548.71,
#           "city1": "Jackson, WY",
#           "city2": "New York City, NY (Metropolitan Area)",
#           "dst_lat": 40.6413,
#           "dst_lon": -73.7781,
#           "pct_diff": 0.2702777742062903,
#           "predicted_fare": 431.960639744997,
#           "pretty_dif": 0.27,
#           "src_lat": 43.6073,
#           "src_lon": -110.7377,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         4735.114909311061,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1482.8899740888744,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "6404cd3a-0531-41aa-88c1-ef4b8b26e92f",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 549.64,
#           "city1": "Jackson, WY",
#           "city2": "New York City, NY (Metropolitan Area)",
#           "dst_lat": 40.6413,
#           "dst_lon": -73.7781,
#           "pct_diff": 0.2401034573395704,
#           "predicted_fare": 443.2210851013661,
#           "pretty_dif": 0.24,
#           "src_lat": 43.6073,
#           "src_lon": -110.7377,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         2622.912728640668,
#         70,
#         20
#       ],
# ...
#       "getTargetColor": [
#         473.33085003063644,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "ac4de987-80ec-469a-9b49-71afe5b99505",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 339.18,
#           "city1": "Phoenix, AZ",
#           "city2": "Raleigh/Durham, NC",
#           "dst_lat": 35.8776,
#           "dst_lon": -78.7875,
#           "pct_diff": 0.1558714276598438,
#           "predicted_fare": 293.4409415125847,
#           "pretty_dif": 0.16,
#           "src_lat": 33.4373,
#           "src_lon": -112.0078,
#           "suggested_alternatives": "Richmond, VA;Washington, DC (Metropolitan Area);Richmond, VA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         308.80923921001386,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         197.76184784200277,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "ed699dc8-c7e5-46a7-a3bd-4b629c19057a",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 386.02,
#           "city1": "Phoenix, AZ",
#           "city2": "Raleigh/Durham, NC",
#           "dst_lat": 35.8776,
#           "dst_lon": -78.7875,
#           "pct_diff": 0.1678994319333373,
#           "predicted_fare": 330.5250344723463,
#           "pretty_dif": 0.17,
#           "src_lat": 33.4373,
#           "src_lon": -112.0078,
#           "suggested_alternatives": "Richmond, VA;Washington, DC (Metropolitan Area);Richmond, VA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         248.66921784254626,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         185.73384356850926,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "ab3dbbcb-370f-4812-97d8-3f0bbf3c4e44",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 473.21,
#           "city1": "Raleigh/Durham, NC",
#           "city2": "San Francisco, CA (Metropolitan Area)",
#           "dst_lat": 37.6213,
#           "dst_lon": -122.379,
#           "pct_diff": 0.2034165764780248,
#           "predicted_fare": 393.2221055030823,
#           "pretty_dif": 0.2,
#           "src_lat": 35.8776,
#           "src_lon": -78.7875,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         71.08349511910882,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         150.21669902382177,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "24d4fe7b-aa71-46c8-a5ba-84b8ee70284f",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 465.35,
#           "city1": "Raleigh/Durham, NC",
#           "city2": "San Diego, CA",
#           "dst_lat": 32.7338,
#           "dst_lon": -117.1933,
#           "pct_diff": 0.1664654079566988,
#           "predicted_fare": 398.9402487426996,
#           "pretty_dif": 0.17,
#           "src_lat": 35.8776,
#           "src_lon": -78.7875,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         255.83933772573877,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         187.16786754514774,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "62f280f7-e6cc-4428-99e5-8bb1227899da",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 397.64,
#           "city1": "Salt Lake City, UT",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.1608499991937287,
#           "predicted_fare": 342.5421030074358,
#           "pretty_dif": 0.16,
#           "src_lat": 40.7899,
#           "src_lon": -111.9791,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         283.9163815405893,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         192.78327630811788,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "8713d328-b5e9-42fb-8685-284a4e21e681",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 262.6,
#           "city1": "San Antonio, TX",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.2259033322762606,
#           "predicted_fare": 214.2093859165907,
#           "pretty_dif": 0.23,
#           "src_lat": 29.5337,
#           "src_lon": -98.4698,
#           "suggested_alternatives": "Seattle, WA;Seattle, WA;Seattle, WA"
#         }
#       ],
#       "getSourceColor": [
#         1628.903974208983,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         595.4011354882809,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "f7be0ead-f352-445b-a6fc-4fda6d5f4a53",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 397.84,
#           "city1": "San Francisco, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.152932208434854,
#           "predicted_fare": 345.0679901987314,
#           "pretty_dif": 0.15,
#           "src_lat": 37.6213,
#           "src_lon": -122.379,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         323.50533533496287,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         200.70106706699255,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "2085d8ba-cab3-4d05-826b-5bfb0355615d",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 336.49,
#           "city1": "San Francisco, CA (Metropolitan Area)",
#           "city2": "St. Louis, MO",
#           "dst_lat": 38.7487,
#           "dst_lon": -90.37,
#           "pct_diff": 0.1538861291072212,
#           "predicted_fare": 291.61456361413,
#           "pretty_dif": 0.15,
#           "src_lat": 37.6213,
#           "src_lon": -122.379,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         318.7357319731269,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         199.7471463946254,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "f3e118ae-af0d-4809-8768-af66c3aa3df6",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 419.39,
#           "city1": "San Francisco, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1869696970618656,
#           "predicted_fare": 353.3283124566078,
#           "pretty_dif": 0.19,
#           "src_lat": 37.6213,
#           "src_lon": -122.379,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         153.31789219990492,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         166.663578439981,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "fd7ddf4f-d642-4687-b3a8-5850db39a650",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 369.4,
#           "city1": "San Francisco, CA (Metropolitan Area)",
#           "city2": "St. Louis, MO",
#           "dst_lat": 38.7487,
#           "dst_lon": -90.37,
#           "pct_diff": 0.1689853834306734,
#           "predicted_fare": 316.0005293786526,
#           "pretty_dif": 0.17,
#           "src_lat": 37.6213,
#           "src_lon": -122.379,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         243.23946035586582,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         184.64789207117317,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "fcd0d452-02f0-4c04-90d3-f2739e150fcb",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 315.04,
#           "city1": "San Francisco, CA (Metropolitan Area)",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.1578344686419757,
#           "predicted_fare": 272.0941624492407,
#           "pretty_dif": 0.16,
#           "src_lat": 37.6213,
#           "src_lon": -122.379,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         298.9940342993543,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         195.79880685987087,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "6d8a04a6-9571-437b-8d7e-2bcf7a09fa1d",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 318.06,
#           "city1": "Seattle, WA",
#           "city2": "St. Louis, MO",
#           "dst_lat": 38.7487,
#           "dst_lon": -90.37,
#           "pct_diff": 0.2482264141859902,
#           "predicted_fare": 254.80954127013683,
#           "pretty_dif": 0.25,
#           "src_lat": 47.4502,
#           "src_lon": -122.3088,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Washington, DC (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         3191.5197078900546,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1041.8627736828726,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "95834bad-3fc4-4a50-b6cd-846cd9b55775",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 391.59,
#           "city1": "Seattle, WA",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1589832562052953,
#           "predicted_fare": 337.8737336397171,
#           "pretty_dif": 0.16,
#           "src_lat": 47.4502,
#           "src_lon": -122.3088,
#           "suggested_alternatives": "Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area);Washington, DC (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         293.25009648275636,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         194.65001929655128,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "51ccf571-5637-4415-8697-12f7c1c5657f",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 349.78,
#           "city1": "Seattle, WA",
#           "city2": "St. Louis, MO",
#           "dst_lat": 38.7487,
#           "dst_lon": -90.37,
#           "pct_diff": 0.2752395448927581,
#           "predicted_fare": 274.28572255373,
#           "pretty_dif": 0.28,
#           "src_lat": 47.4502,
#           "src_lon": -122.3088,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Washington, DC (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         5082.438857363807,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1582.1253878182306,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "9d075bdc-50eb-4e80-985c-6e4e51cfdd1e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 398.3,
#           "city1": "Seattle, WA",
#           "city2": "Washington, DC (Metropolitan Area)",
#           "dst_lat": 38.9531,
#           "dst_lon": -77.4565,
#           "pct_diff": 0.1963556636988414,
#           "predicted_fare": 332.9277505725622,
#           "pretty_dif": 0.2,
#           "src_lat": 47.4502,
#           "src_lon": -122.3088,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         70,
#         106.3880590150259,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         150,
#         157.2776118030052,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "8e4db928-76a1-4de6-a2f1-35c0603aecb4",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 341.92,
#           "city1": "Seattle, WA",
#           "city2": "St. Louis, MO",
#           "dst_lat": 38.7487,
#           "dst_lon": -90.37,
#           "pct_diff": 0.2409298476295554,
#           "predicted_fare": 275.53531785309315,
#           "pretty_dif": 0.24,
#           "src_lat": 47.4502,
#           "src_lon": -122.3088,
#           "suggested_alternatives": "Tampa, FL (Metropolitan Area);Washington, DC (Metropolitan Area);Tampa, FL (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         2680.760048939619,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         895.9314425541769,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 1.2,
#       "id": "9af669c1-d480-45c6-af65-41cc54a14db6",
#       "pickable": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %%
# Albany, NY to Los Angeles, CA (Metropolitan Area) flight analysis

layers=[]

for row in df.to_dict(orient="records"):
    # highlight = avg<row["pct_diff"]
    # act_dif =row["pct_diff"] * (-1 if row["actual_fare"] < row["predicted_fare"] else 1)
    # print(row["city1"], )
    check = row["city1"]=="Birmingham, AL" and row["city2"]=="Tampa, FL (Metropolitan Area)"
    # print(dist)
    if not check:
        continue
    print("past check")

    mainlayer = pdk.Layer(
        "ArcLayer",
        data=[row],
        get_source_position=["src_lon", "src_lat"],
        get_target_position=["dst_lon", "dst_lat"],
        get_source_color=[70 +(70000* max((row["pct_diff"]-avg),0)), 70+(5000* max(-(row["pct_diff"]-avg),0)), 20],   # pink at origin
        get_target_color=[150+(20000* max((row["pct_diff"]-avg),0)), 150+(1000* max(-(row["pct_diff"]-avg),0)), 150],   # cyan at destination
        get_width=5,
        pickable=True,
        auto_highlight=True,
    )
    layers.append(mainlayer)
    alternatives = row["suggested_alternatives"].split(";")

    for row2 in df.to_dict(orient="records"):
        
        if not(row2["city1"] in alternatives and row2["city2"] == row["city2"]):
            continue

        for suggested in row["suggested_alternatives"].split(";"):
            suggested_path = pdk.Layer(
                "ArcLayer",
                data=[row2],
                get_source_position=["src_lon", "src_lat"],
                get_target_position=["dst_lon", "dst_lat"],
                get_source_color=[255, 0, 128],
                get_target_color=[0, 200, 255],
                get_width=4,
                pickable=True,
                auto_highlight=True,
            )
            layers.append(suggested_path)



b = pdk.Deck(
    layers=layers,
    initial_view_state=view_state,
    map_style="https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
    tooltip={"html": "{city1} → {city2}\nAvg. Fare: {actual_fare}\n Pred:{predicted_fare} \n Difference from Predicted(ratio): {pretty_dif}"},                       # free, no API key needed
)

# Map of predicted model differences from actual fare prices for long distance flights only 
b
# Out:
# past check
# past check
# {
#   "initialViewState": {
#     "bearing": 20,
#     "latitude": 40.0,
#     "longitude": -100.0,
#     "pitch": 60,
#     "zoom": 3.5
#   },
#   "layers": [
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 242.27,
#           "city1": "Birmingham, AL",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2878755167871519,
#           "predicted_fare": 188.11600720882416,
#           "pretty_dif": 0.29,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         5966.956889971373,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         1834.8448257061066,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 5,
#       "id": "496d4d57-5eba-4f0c-be6f-7421cb83b9b6",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "7680b15e-406f-46b4-8d50-a455a7795b9b",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "0eae025a-e7d4-45ea-bf40-bdbbf32c5512",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "9f056bf8-1bc2-4bfd-9247-8ae50f2668c8",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "e519cc18-81ac-45fe-8d8e-9bbf4b56f335",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "c991469b-44d9-471a-8162-0d0d8540e63e",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "8652405e-f22e-4d15-976d-b3b6dca722ce",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 239.57,
#           "city1": "Birmingham, AL",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.3789644188915873,
#           "predicted_fare": 173.73182129859924,
#           "pretty_dif": 0.38,
#           "src_lat": 33.5629,
#           "src_lon": -86.7535,
#           "suggested_alternatives": "Los Angeles, CA (Metropolitan Area);Las Vegas, NV;Los Angeles, CA (Metropolitan Area)"
#         }
#       ],
#       "getSourceColor": [
#         12343.180037281849,
#         70,
#         20
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         3656.6228677948143,
#         150,
#         150
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 5,
#       "id": "45026eff-215f-40aa-980e-d8ef89d2b8b7",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "c4f21e82-5abc-48f0-97d8-e82a843c2675",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "724e9247-9738-4003-831b-75401a7938e0",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 342.82,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.2392451980494987,
#           "predicted_fare": 276.6361334621906,
#           "pretty_dif": 0.24,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "4349551e-7a08-41d6-8cdf-1ec90363e6b3",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "8dae4d7e-cc15-4366-a044-b13a258867cc",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "8f3a9e04-4503-43b5-b013-6e2a7bdb75c4",
#       "pickable": true
#     },
#     {
#       "@@type": "ArcLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "actual_fare": 368.27,
#           "city1": "Los Angeles, CA (Metropolitan Area)",
#           "city2": "Tampa, FL (Metropolitan Area)",
#           "dst_lat": 27.9755,
#           "dst_lon": -82.5332,
#           "pct_diff": 0.1914572140908743,
#           "predicted_fare": 309.0920896232128,
#           "pretty_dif": 0.19,
#           "src_lat": 33.9425,
#           "src_lon": -118.4081,
#           "suggested_alternatives": "Orlando, FL;Washington, DC (Metropolitan Area);Pittsburgh, PA"
#         }
#       ],
#       "getSourceColor": [
#         255,
#         0,
#         128
#       ],
#       "getSourcePosition": "@@=[src_lon, src_lat]",
#       "getTargetColor": [
#         0,
#         200,
#         255
#       ],
#       "getTargetPosition": "@@=[dst_lon, dst_lat]",
#       "getWidth": 4,
#       "id": "e9ae9c9d-b70e-4db4-8822-a80f90c12757",
#       "pickable": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }
